# %%
#a, b, *c = 2, 4, 6,8,10,20
a, *b, c = 2, 4, 6,8,10,20
print(a, b, c)
# Out:
# 2 [4, 6, 8, 10] 20

# %%
email = """Dear Sanjay, 
            How are you doing? 
            Thank You John"""
print(email)
# Out:
# Dear Sanjay,
#             How are you doing?
#             Thank You John

# %%
# Escape Characters
sentence = 'It\'s a rainy day'

sentence = 'It\'s \na rainy day'

sentence = 'It\'s \ta rainy day'

print(sentence)
# Out:
# It's 	a rainy day

# %%
# Checking string Content

text = "Hello 123"

# print(text.isalnum())
print(text.isdigit())
print(text.isupper())
print(text.islower())
print(text.isspace())
# Out:
# False
# False
# False
# True

# %%
# String Formatting

name = "Subash"
amount = 5000
# sentence = f" Dear {name + ' kumar'}, your invoice is pending"
# sentence = f" Dear {name}, your invoice of Rs.{amount}/- is pending"

# sentence = "Dear {}, your invoice of Rs.{}/- is Pending".format(name,amount)
# sentence = "Dear {0}, your invoice of Rs.{1}/- is Pending".format(name,amount)

# sentence = "Dear {name}, your invoice of Rs.{amount}/- is Pending".format(name = "Charlie",amount = "1000")

print(sentence)
# Out:
# Dear 5000, your invoice of Rs.Subash/- is Pending
