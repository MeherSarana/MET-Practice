# %%
# 2. Tuples
# Creating Tuples

# colours = ("yellow","green","black")
# print(colours[1:4]) ('green', 'black')
# empty_tuple = ()
# b = tuple()
# c = "yellow","green","black"
# d = ("Hello")  <class 'str'>
# e = ("Hello",) <class 'tuple'>
# print(empty_tuple) ()
# print(b) ()
# print(type(c)) <class 'tuple'>
# print(type(d))
# print(type(e))
# Out:
# <class 'tuple'>

# %%
# Access Elements 
c = ("yellow","green","black")
print(c[2])
print(c[-2])
print(c[1:3])
print(c[:2])
print(c[-3:-1])

# %%
# Updating Elements in Tuple
# a - Type Conversion to List and tuple
# c = ("yellow","green","black")
# d = list(c)
# d.insert(2,"white")
# d.append("orange")
# print(type(d))
# c = tuple(d)
# print(type(c),"\n",c)

# b - adding two tuples
# a = ("a","b","c")
# b = ("x","y","z")
# c = a + b
# print(c)
# Out:
# ('a', 'b', 'c', 'x', 'y', 'z')

# %%
# Remove Items from tuple
# 1 - Type Convert and Delete Specific ele
# a = ("a","b","c")
# b = list(a)
# b.remove("c")
# a = tuple(b)
# print(a)

# 2 - To delete entire tuple
a = ("a","b","c")
del a
print(a)
# Out:
# ('a', 'b')

# %%
# Tuple Unpacking

fruits = ("apple","banana","kiwi","dragon")

a,b,*c = fruits
print(c)
# Out:
# ['kiwi', 'dragon']

# %%
# Helper methods
# We also use max,min methods as well
print(len(fruits))
print(fruits.count("apple"))
print(fruits.index("kiwi"))
# Out:
# 4
# 1
# 2

# %%
# 3. Sets
# Unique Ele, Unordered(No indices)
# a.Create sets
# players = {}
# print(type(players)) <class 'dict'>
# players = set()
# print(players) set()
# players = {'john','alex','ally','alex'}
# print(players)

# b.Access Elements
# players = {'john','alex','ally','alex'}
# print(players.pop())
# print(players)

# c.Adding Elements / Updating
# c1
# players = {'john','alex','ally'}
# players.add("jim")
# print(players)

# c2
# a = {'john','alex','ally'}
# # b = {'john','Guy'}
# b = ('john','Guy')
# a.update(b) 
# print(a) 

a = {'john','alex','ally'}
b = {'john','lex','Oly'}
c = {'alex','Oly','Newton','john'}
d = a | b | c # Union
print(d)
z = a & b & c # intersection
print(z)

# # d.Removing Elements from Set
# a = {'john','alex','ally'}
# # print(a.pop())
# # a.remove("alex") #Hard Removal Search and Destroy or Err0r
# a.discard("alex") #Soft Removal Search,delete and display
# a.clear()
# del a
# print(a)
# Out:
# {'ally', 'Oly', 'john', 'alex', 'Newton', 'lex'}
# {'john'}
