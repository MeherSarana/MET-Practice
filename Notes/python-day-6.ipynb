# %%
# 1. Creating List
# fruits = []
# fruits = list()
# numbers = [1,2,3,4,]
# fruits = ["apple","banana",]
# mixed = ["apple","banana",1,2,True]
fruits = ["apple","banana","cherry",]
# print(fruits[0])
# print(fruits[-1])

# 2. Add/ Update List
# 3. Delete 
# 4. Search and Count
# 5. Sort and Order
# 6. Helper Methods
# Out:
# apple

# %%
#2. Add/ Update List

fruits = ["apple","banana","cherry",]
fruits2 = ["Pineapple", "Mango"]
# 2a. fruits[0] = "pear" #['pear', 'banana', 'cherry']
# 2b. fruits.append("dragon") #['apple', 'banana', 'cherry', 'dragon']
# 2c. fruits.insert(1,"Mango") #['apple', 'Mango', 'banana', 'cherry']
# 2d. fruits.extend(fruits2) #['apple', 'banana', 'cherry', 'Pineapple', 'Mango']
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'Pineapple', 'Mango']

# %%
# 3. Delete
fruits = ["apple","banana","cherry",]
# 3a. a = fruits.pop()
# 3b. a = fruits.pop(1) Pop Method Returns 
# 3c. fruits.remove("apple") No Return
# 3d. del fruits[2]
# 3e. del fruits
# 3f. fruits.clear() To Clear elements in the List
print(fruits,a)
# Out:
# []

# %%
# 4. Search and Count

fruits = ["apple","banana","cherry",]
#4a i = fruits.index("apple")
#4b i = fruits.count("banana")
print(i)
# Out:
# 1
# ['apple', 'banana', 'cherry']

# %%
# 5. Sort and Order
fruits = ["banana","kiwi","cherry","apple",]
# 5a. fruits.sort()
# 5b. fruits.sort(reverse=True) desc
# 5c. fruits.reverse()

print(fruits)
# Out:
# ['apple', 'cherry', 'kiwi', 'banana']

# %%
# 6. Helper Methods
fruits = ["banana","kiwi","apple","kiwi","kiwi"]
num = [2,3,6,8]
#print(fruits[fruits.index("apple")])
#print(4 in num)
# 6a. i = len(fruits)
# 6b. r = sum(num)
# 6c. r = max(num)
# 6d. q = min(num)
print(r,q)
# Out:
# 8 2

# %%
words = ["wakeup", "Exercise", "Work", "Hello"]
# print(words[-3:-1])
print(words[0][3])
# words.pop(2)
# words.reverse()
# print(words)
# Out:
# e
