# %%
# Dictionary

# Creation
# a = {}
# person = {
#     "name" : "Alex",
#     "age" : 25
# }

# a = person["name"]
# a = person.get("address","Hyderabad")

# Modificaton
# person["age"] = 35
# person.update({"age":35,"address":"Hyderabad"})
# print(person)

# Deletion

# person = {
#     "name" : "Alex",
#     "age" : 25
# }

# age = person.pop('age')
# a = person.popitem()
# del person["name"]
# person.clear()

# print(person)

# Helper Methods

person = {
    "age" : 25,
    "name" : "Alex",
}

# a = person.keys() 
# a = person.values()
# a = person.items()
# Shallow Copy
# person_2 = person  dependent on person
# person["age"] = 35 
# print(person_2["age"]) 35

# person_2 = person.copy() both independent dicts
# person["age"] = 35
# print(person_2["age"]) 25

user = {'name':'john'}
# user2 = {'age':25}

# merge_users = {**user,**user2}
# print(merge_users)

# how to check elements in dict
print("john" in list(user.values()))
# Out:
# True
