# %%
#1
fruits = ["Apple", "Banana","Cherry","Dragon","Blue Berry"]
print(fruits[0])
print(fruits[-1])
# Out:
# Apple
# Blue Berry

# %%
2#
city = []
a = input("Enter the three Cities Visited Recently:")
city.append(a)
print(city)
# Out:
# Enter the three Cities Visited Recently: delhi, chennai, banglore
# ['delhi, chennai, banglore']

# %%
#3
prices =  [1200, 850, 950, 720]
prices.sort(reverse = True)
print(prices[2:])
# Out:
# [850, 720]

# %%
#4
even = [2,4,6,8,10]
even.append(12)
print(even)
# Out:
# [2, 4, 6, 8, 10, 12]

# %%
#5
lang =  ['Java', 'C++', 'Go'] 
lang.insert(1,"Python")
print(lang)
# Out:
# ['Java', 'Python', 'C++', 'Go']

# %%
#6
sentence = input("Enter a Sentence").split(" ")
print(sentence)
# Out:
# Enter a Sentence Python is awesome
# ['Python', 'is', 'awesome']

# %%
#7
months =  ['Jan', 'Feb', 'Mar', 'Apr']
months.pop()
print(months)
# Out:
# ['Jan', 'Feb', 'Mar']

# %%
#8
vehicle =  ['car', 'bus', 'train']
vehicle.sort(reverse = True)
print(vehicle)
# Out:
# ['train', 'car', 'bus']

# %%
#9
fruits = ['apple', 'banana', 'apple', 'cherry']
i = fruits.count("apple")
print(i)
# Out:
# 2

# %%
#10
num1= 3
num2= 5
fruit1= "apples"
fruit2= "bananas"
 
print("Tom has {} {} and {} {}.".format(num1, fruit1, num2, fruit2))
# Out:
# Tom has 3 apples and 5 bananas.

# %%
#11
string = "hello"
chars = list(string)
print(chars)
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
#12
nums = [1,2,3,4,5,6]
r = sum(nums)
a = sum(nums)/len(nums)
print("The sum is ",r," and the average is ",a)
# Out:
# The sum is  21  and the average is  3.5

# %%
#13
name = input("Enter your Name:")
name_l = list(name)
name_l.reverse()
print(name_l)
# Out:
# Enter your Name: wander
# ['r', 'e', 'd', 'n', 'a', 'w']

# %%
#14
names = ['Alice', 'Bob', 'Charlie']
print("Bob" in names)
# Out:
# True

# %%
#15
nums_names = ['one', 'two', 'three']
nums_names.clear()
print(nums_names)
# Out:
# []
