# %%
#1 
lang = {"Python","Java","C++"}
print(lang)
# Out:
# {'Java', 'C++', 'Python'}

# %%
#2
hobbies = input("Enter the Hobbies: ").split(" ")
a = set(hobbies)
print(a)
# Out:
# Enter the Hobbies:  Run Swim Read
# {'Swim', 'Run', 'Read'}

# %%
#3
colours = {'red', 'blue', 'green'}
colours.add("yellow")
print(colours)
# Out:
# {'red', 'blue', 'green', 'yellow'}

# %%
#4
fruits1 = {'apple', 'banana'}
fruits2 = {'banana', 'cherry'}

fruits1.update(fruits2)
print(fruits1)
# Out:
# {'cherry', 'apple', 'banana'}

# %%
#5
a = {'Delhi','Bombay','Chennai'}
b = {"Hyd","Bangalore"}
c = a | b
print(c)
# Out:
# {'Bombay', 'Bangalore', 'Hyd', 'Delhi', 'Chennai'}

# %%
#6
a = {'alex', 'john', 'mike'}
b = {'john', 'mike', 'lisa'}
c = a&b
print(c)
# Out:
# {'mike', 'john'}

# %%
#7
items = {'pen', 'pencil', 'eraser'}
items.discard('pencil')
print(items)
# Out:
# {'pen', 'eraser'}

# %%
#8
items = {'pen', 'pencil', 'eraser'}
items.remove()
print(items)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_35/785833765.py in <cell line: 0>()
#       1 #8
#       2 items = {'pen', 'pencil', 'eraser'}
# ----> 3 items.remove()
#       4 print(items)
#
# TypeError: set.remove() takes exactly one argument (0 given)

# %%
#9
weekdays = {'mon','tue','wed','thr','fri','sat'}
weekdays.pop()
print(weekdays)
# Out:
# {'wed', 'tue', 'mon', 'fri', 'sat'}

# %%
#10
car_brands = {"BMW","Volvo","Merc-Benz","Tata","Subaru"}
car_brands.clear()
print(car_brands)
# Out:
# set()

# %%
#11
tools = {'hammer','drill','Srew Driver','Cutting Player'}
del tools
print(tools)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_35/3980842060.py in <cell line: 0>()
#       2 tools = {'hammer','drill','Srew Driver','Cutting Player'}
#       3 del tools
# ----> 4 print(tools)
#
# NameError: name 'tools' is not defined

# %%
#12
string = 'hello'
a = set(string)
print(a)
# Out:
# {'h', 'e', 'o', 'l'}

# %%
#13
user = input("Enter Five Words:").split(" ")
a = set(user)
print(a)
# Out:
# Enter Five Words Run Gun Sun Math Jump
# {'Gun', 'Sun', 'Math', 'Run', 'Jump'}

# %%
#14
a = {'a', 'b', 'c'}
b = {'c', 'd', 'e'}
unique_to_a = a.difference(b)
print(unique_to_a)
# Out:
# {'b', 'a'}

# %%
#15
items_room = {"Controller","Headphones","Chair","Draw","Mouse"}
items_room.add("Keyboard")
print(len(items_room))
# Out:
# 6
